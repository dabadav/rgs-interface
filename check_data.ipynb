# %%
import pandas as pd

# %%
data = pd.read_csv("rgs_interactions.csv")
data
# Out:
#    PATIENT_ID  HOSPITAL_ID PATIENT_USER PATIENT_CREATION_TIME  DELETE_TIME  \
# 0        3588          175       Menzel   2025-02-05 13:02:24          NaN
# 1        3588          175       Menzel   2025-02-05 13:02:24          NaN
# 2        3588          175       Menzel   2025-02-05 13:02:24          NaN
# 3        3588          175       Menzel   2025-02-05 13:02:24          NaN
# 4        3588          175       Menzel   2025-02-05 13:02:24          NaN
# 5        3588          175       Menzel   2025-02-05 13:02:24          NaN
#
#    NAME  SURNAME1  SURNAME2 PARETIC_SIDE UPPER_EXTREMITY_TO_TRAIN  ...  \
# 0   NaN       NaN       NaN         NONE                     BOTH  ...
# 1   NaN       NaN       NaN         NONE                     BOTH  ...
# 2   NaN       NaN       NaN         NONE                     BOTH  ...
# 3   NaN       NaN       NaN         NONE                     BOTH  ...
# 4   NaN       NaN       NaN         NONE                     BOTH  ...
# ...
